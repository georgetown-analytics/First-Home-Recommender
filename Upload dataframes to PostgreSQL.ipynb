# %%
import pandas as pd
import psycopg2

conn = psycopg2.connect( 
                        host = 'project.cgxhdwn5zb5t.us-east-1.rds.amazonaws.com',
                        port = 5432, 
                        user = 'postgres',
                        password = 'Admin123',
                        database = 'postgres')
cursor = conn.cursor()

# %%
classdata = pd.read_csv("AHS_Household_Class_updated.csv")

# %%
classdata2 = pd.read_csv("AHSHouseholdClass.csv")

# %%
regdata = pd.read_csv("AHS_Household_Reg_updated.csv")

# %%
firsthome = pd.read_csv("AHS_Household_First_Home_updated.csv")

# %%
nonexp = pd.read_csv("AHS_Household_nonexperience_variables_with_missings.csv")

# %%
old

# %%
classdata2.head(10)
# Out:
#    Unnamed: 0     CONTROL    YEAR  RATINGHS  NUMSECFAM  NUMNONREL  NUMSUBFAM  \
# 0           0  11000006.0  2017.0      10.0        0.0        0.0        0.0
# 1           1  11000016.0  2017.0       8.0        0.0        0.0        0.0
# 2           2  11000017.0  2017.0       9.0        0.0        1.0        0.0
# 3           3  11000023.0  2017.0       8.0        0.0        0.0        0.0
# 4           4  11000046.0  2017.0      10.0        0.0        0.0        0.0
# 5           5  11000048.0  2017.0       9.0        0.0        0.0        0.0
# 6           6  11000052.0  2017.0       5.0        0.0        0.0        0.0
# 7           7  11000054.0  2017.0       8.0        0.0        0.0        0.0
# 8           8  11000062.0  2017.0       6.0        0.0        0.0        0.0
# 9           9  11000066.0  2017.0       4.0        0.0        0.0        1.0
#
#    PERPOVLVL  NUMVETS  HHYNGKIDS  ...  GARAGE  DISHWASH  FIRSTHOME  CONDO  \
# ...

# %%
regdata.head(10)

# %%
firsthome.head(10)

# %%
nonexp.head(10)

# %%
from sqlalchemy import create_engine

engine = create_engine('postgresql://postgres:Admin123@project.cgxhdwn5zb5t.us-east-1.rds.amazonaws.com:5432/postgres')
classdata.to_sql('ahshouseholdclass2', engine)

# %%
engine = create_engine('postgresql://postgres:Admin123@project.cgxhdwn5zb5t.us-east-1.rds.amazonaws.com:5432/postgres')
regdata.to_sql('ahshouseholdreg', engine)

# %%
engine = create_engine('postgresql://postgres:Admin123@project.cgxhdwn5zb5t.us-east-1.rds.amazonaws.com:5432/postgres')
firsthome.to_sql('ahshouseholdfirsthome', engine)

# %%
engine = create_engine('postgresql://postgres:Admin123@project.cgxhdwn5zb5t.us-east-1.rds.amazonaws.com:5432/postgres')
nonexp.to_sql('ahshouseholdnonexp', engine)

# %%
set(classdata.columns).symmetric_difference(set(classdata2.columns))
# Out:
# {'LN_FINCP', 'LN_HINCP', 'RATINGHS', 'RATINGHS_BIN'}
